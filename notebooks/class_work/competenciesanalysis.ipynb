# %%
 # !pip install pandas matplotlib numpy
 import pandas as pd
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
df = pd.read_csv("Competencies1.csv")
df
# Out:
#    Student      Program        Course          Competency  Hours_Studied  \
# 0    Alice  Informatics  Data Science          Statistics             12
# 1    Alice  Informatics  Data Science         Programming             11
# 2    Alice  Informatics  Data Science    Machine Learning             13
# 3    Alice  Informatics  Data Science  Data Visualization             10
# 4    Alice  Informatics  Data Science            Big Data             14
# ..     ...          ...           ...                 ...            ...
# 85   Tomas  Informatics  Data Science            Big Data             14
# 86  Ursula    Education     Education            Pedagogy              8
# 87  Ursula    Education     Education          Assessment              9
# 88  Ursula    Education     Education   Curriculum Design             10
# 89  Ursula    Education     Education  Learning Analytics             11
#
#     Grade
# 0      88
# 1      84
# 2      90
# 3      82
# 4      92
# ..    ...
# ...

# %%
df.head()       #first rows
df.describe()   #statistics
# Out:
#        Hours_Studied      Grade
# count      90.000000  90.000000
# mean       11.711111  83.311111
# std         2.399646   8.525763
# min         7.000000  65.000000
# 25%        10.000000  76.000000
# 50%        12.000000  84.500000
# 75%        13.750000  90.000000
# max        17.000000  99.000000

# %%
program_points = df.groupby("Program")["Grade"].mean().sort_values(ascending=False)
program_points
program_points.plot(kind="bar")
plt.title("Average points per program")
plt.ylabel("points")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 program_points
#       3 program_points.plot(kind="bar")
# ----> 4 plt.title("Average points per program")
#       5 plt.ylabel("points")
#       6 plt.show()
#
# NameError: name 'plt' is not defined

# %%
course_points = df.groupby("Course")["Grade"].mean().sort_values(ascending=False)
course_points
# Out:
# Course
# Education       83.675
# Data Science    83.020
# Name: Grade, dtype: float64

# %%
#which course has the highest average student performance? 
avg_course = df.groupby("Course") ["Grade"]. mean()																									
print("Average Grade per Course: \n", avg_course, "\n")																									

avg_course.plot(kind="bar", figsize=(8,5), color="orchid")																									
plt.title("Average Grade per Course")																									
plt.ylabel("Average Grade")																									
plt.show()
# Out:
# Average Grade per Course:
#  Course
# Data Science    83.020
# Education       83.675
# Name: Grade, dtype: float64

# %%
#which progran has the highest average student performance? 
avg_program = df.groupby("Program")["Grade"].mean()																									
print("Average Grade per Program: \n", avg_program, "\n")																									
																									
avg_program.plot(kind="bar", figsize=(6,4), color="gold")																									
plt.title("Average Grade per Program")																									
plt.ylabel("Average Grade")																									
plt.show()
# Out:
# Average Grade per Program:
#  Program
# Education      83.675
# Informatics    83.020
# Name: Grade, dtype: float64

# %%
plt.figure(figsize=(8,5))
df[["Hours_Studied","Grade"]].boxplot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
age_min = df["Age"].min()
age_q1 = df["Age"].quantile(0.25)
age_q3 = df["Age"].quantile(0.75)
age_max = df["Age"].max()

yop_min = df["Years of practice"].min()
yop_q1 = df["Years of practice"].quantile(0.25)
yop_q3 = df["Years of practice"].quantile(0.75)
yop_max = df["Years of practice"].max()

print("Years of practice - Min:", yop_min, "Q1", yop_q1, "Q3", yop_q3, "Max", yop_max)
print("Age - Min:", age_min, "Q1", age_q1, "Q3", age_q3, "Max", age_max)

#Drw box plot
plt.figure(figsize=(8,5)) #kui tahad suurust muuta, muuda figsize'i
df[["Age", "Years of practice"]].boxplot() #boxploti loomiseks piisab siia "years of practice" i lisamisest
plt.title("Box plot for age and years of practice") #saad panna pealkirja 
plt.show

# %%
import matplotlib.pyplot as plt

avg_hours = df.groupby("Student")["Hours_Studied"].mean().sort_values(ascending=False)
avg_hours.plot(kind="bar")
plt.title("Average hours studied")
plt.ylabel("hours")
plt.show()

# %%
avg_hours
# Out:
# Student
# Alice      87.20
# Bob        74.80
# Clara      89.75
# David      72.00
# Ella       92.20
# Frank      83.50
# Gina       76.40
# Hugo       90.75
# Ingrid     94.60
# Jack       70.50
# Katrin     75.20
# Leo        88.75
# Maria      91.40
# Nikolai    82.50
# Oskar      80.80
# Paula      93.00
# Rasmus     72.00
# Sandra     90.00
# Tomas      85.60
# Ursula     76.00
# Name: Grade, dtype: float64

# %%
avg_points = df.groupby("Student")["Grade"].mean().sort_values(ascending=False)
avg_points.plot(kind="bar")
plt.title("Best perfomer")
plt.ylabel("average points")
plt.show()

# %%
avg_points
# Out:
# Student
# Alice      87.20
# Bob        74.80
# Clara      89.75
# David      72.00
# Ella       92.20
# Frank      83.50
# Gina       76.40
# Hugo       90.75
# Ingrid     94.60
# Jack       70.50
# Katrin     75.20
# Leo        88.75
# Maria      91.40
# Nikolai    82.50
# Oskar      80.80
# Paula      93.00
# Rasmus     72.00
# Sandra     90.00
# Tomas      85.60
# Ursula     76.00
# Name: Grade, dtype: float64

# %%
avg_points = df.groupby("Student")["Grade"].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 8))

plt.pie(avg_points, labels=avg_points.index, autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ebcd7946b10>,
# ...
#  [Text(-0.9546857168983962, 0.5464203344955194, 'Ingrid'),
#   Text(-1.084826699339644, 0.18207424968911418, 'Paula'),
#   Text(-1.0816829632471059, -0.1999048949399699, 'Ella'),
#   Text(-0.9497731310760874, -0.5549153083903214, 'Maria'),
#   Text(-0.7075820298394915, -0.8422159289922183, 'Hugo'),
#   Text(-0.3855409272569917, -1.0302223999747915, 'Sandra'),
#   Text(-0.021264836483690413, -1.099794438397159, 'Clara'),
#   Text(0.3429673538819293, -1.0451666824823818, 'Leo'),
#   Text(0.6645454037858859, -0.8765725333975815, 'Alice'),
#   Text(0.9100653384894958, -0.6178843578534737, 'Tomas'),
#   Text(1.0578383069461113, -0.3016257886146098, 'Frank'),
#   Text(1.099322991661184, 0.03858704452409468, 'Nikolai'),
#   Text(1.0359811797956286, 0.3697877703619433, 'Oskar'),
#   Text(0.8828882143365858, 0.6561313900321756, 'Gina'),
#   Text(0.6608492710628243, 0.8793624059144979, 'Ursula'),
# ...

# %%
plt.figure(figsize=(8, 8))
plt.pie(avg_points, labels=avg_points.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(avg_hours, avg_points, s=avg_hours*30, alpha=0.6)
plt.xlabel("Hours")
plt.ylabel("Points")
plt.title("Correlation between hours studied and points achieved")
plt.show()

# %%
plt.scatter(df["Hours_Studied"], df["Grade"], s=df["Hours_Studied"]*30, alpha=0.6)
plt.xlabel("Hours")
plt.ylabel("Points")
plt.title("Correlation between hours studied and points achieved")
plt.show()

# %%
"plt.scatter(df[""Age""], df[""Years_of_practice""], s=df[""Years_of_practice""]*30, alpha=0.6)
plt.xlabel(""Age"")
plt.ylabel(""Years_of_practice"")
plt.title(""Age vs years of practice per athlete"")
plt.show()"
# Out:
#   Cell In[1], line 1
#     "plt.scatter(df[""Age""], df[""Years_of_practice""], s=df[""Years_of_practice""]*30, alpha=0.6)
#                                                                                   ^
# SyntaxError: unterminated string literal (detected at line 1)
